# %% [markdown]
# # SAFE Metric: Basic Usage Tutorial
#
# This notebook demonstrates how to use the SAFE (Semantic-Aware Flexible Evaluation) metric.

# %%
import sys
sys.path.insert(0, '..')

from safe_metric import SAFEMetric, QuadEvaluator
import pandas as pd

# %% [markdown]
# ## Example: The Canonical Case
#
# Exact-match F1 = 0.00, but SAFE recognizes semantic equivalence.

# %%
safe = SAFEMetric(tau=70.0)

gold = ("service", "quality", "bad smell", "negative")
pred = ("service", "quality", "very bad smell", "negative")

score = safe.calculate_quad_score(gold, pred)
print(f"SAFE score: {score:.2f}  (Exact F1: 0.00)")
